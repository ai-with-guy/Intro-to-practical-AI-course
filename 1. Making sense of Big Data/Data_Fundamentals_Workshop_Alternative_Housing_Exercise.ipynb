# %% [markdown]
# # California Housing - Pandas Exercise
# Welcome to your Pandas exercise! The data is already downloaded as `california_housing.csv`. Follow the instructions in each markdown cell and write your code in the empty cells below them.

# %% [markdown]
# ### About the Dataset
# This dataset is based on the 1990 California Census. **Important:** Each row represents a "block group" (or district), not a single house. Because of this, columns like `total_rooms` show the total number of rooms across *all* houses in that district combined. You will need to calculate averages (like rooms per household) yourself!

# %% [markdown]
# ### 1. Import Pandas
# Import the pandas library as `pd`.

# %% [markdown]
# ### 2. Load the Dataset
# Load the `california_housing.csv` dataset into a DataFrame called `df`.

# %% [markdown]
# ### 3. Inspect the Data
# Use the `.head()` method to display the first 5 rows and see the basic layout of the dataframe.

# %% [markdown]
# ### 4. Basic Information
# Use a single method to output the number of rows, columns, and data types of your DataFrame.

# %% [markdown]
# ### 5. Summary Statistics
# Display basic summary statistics (mean, median, standard deviation, min, max, etc.) for the numerical columns.

# %% [markdown]
# ### 6. Checking Conditions (Filtering)
# Create a new DataFrame called `expensive_houses` containing only the rows where `median_house_value` is greater than 350000.
# How many such districts are there? (Hint: use `len()` or `.shape`)

# %% [markdown]
# ### 7. Multiple Conditions
# Find all districts where the `housing_median_age` is less than 10 years **AND** the `ocean_proximity` is `'NEAR BAY'`.

# %% [markdown]
# ### 8. Modifying Columns: Creating a new column
# The dataset has `total_rooms` and `households`. Create a new column in `df` named `rooms_per_household` that is the result of dividing `total_rooms` by `households`.
# Display the first 5 rows to verify.

# %% [markdown]
# ### 9. Modifying Columns: Rounding Values
# Let's clean up the `median_income` column. Overwrite the `median_income` column so that all its values are rounded to 2 decimal places.

# %% [markdown]
# ### 10. Advanced: Groupby
# What is the average `median_house_value` for each category in `ocean_proximity`? Group by `ocean_proximity` and calculate the mean.

# %% [markdown]
# ### 11. Advanced: Top 5
# What are the top 5 most populated districts? Sort the DataFrame by `population` in descending order and display the top 5 rows.

# %% [markdown]
# ### 12. Advanced Aggregation
# Using `.groupby()` and `.agg()`, find the `min`, `max`, and `mean` of the `median_house_value` for each category in `ocean_proximity`.

# %% [markdown]
# ### 13. Applying Custom Functions
# Create a new column called `income_category`. Use the `.apply()` method (with a lambda function or standard function) to label districts as `'High Income'` if their `median_income` is greater than 5.0, and `'Normal Income'` otherwise.
# Display the first 5 rows to verify.
