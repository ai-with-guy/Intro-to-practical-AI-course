# %% [markdown]
# # 🐧 Penguins Dataset Concept Check

# %%
import utils

# %% [markdown]
# ### Question 1

# %%
utils.build_question(1)

# %% [markdown]
# ### Question 2

# %%
utils.build_question(2)

# %% [markdown]
# ### Question 3

# %%
utils.build_question(3)

# %% [markdown]
# ### Question 4

# %%
utils.build_question(4)

# %% [markdown]
# ### Question 5

# %%
utils.build_question(5)

# %% [markdown]
# ### Question 6

# %%
utils.build_question(6)

# %% [markdown]
# ### Question 7

# %%
utils.build_question(7)

# %% [markdown]
# ### Question 8

# %%
utils.build_question(8)
